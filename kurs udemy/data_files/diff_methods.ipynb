# %%
import pandas

# %%
df1=pandas.read_csv("data_files\\data.txt", header=None)
df1

# %%
df1.columns = ["ID", "Adress", "City", "ZIP", "Country", "Name", "Employees"]
df1

# %%
df1.set_index("ID", inplace=True, drop=False)
df1

# %%
df1.loc["2":"5","City":"Name"]

# %%
df1.loc[:,"Name"]

# %%
df1.loc[5,"ZIP"]

# %%
list(df1.loc[:,"Name"])

# %%
df1

# %%
df1.iloc[1:4, 1:4]

# %%
df2=pandas.read_csv("data_files\\data.txt", header=None)
df2.columns = ["ID", "Adress", "City", "ZIP", "Country", "Name", "Employees"]
df2.set_index("Name", inplace=True, drop=False)
df2

# %%
df2=df2.drop("Country", 1)
df2.drop("Sanchez", 0, inplace=True)
df2

# %%
df1.shape

# %%
df2["Continent"]=df2.shape[0] * ["North America"]
df2

# %%
df2["Continent"]="America"
df2["Employees"]=df2["Employees"] + 2
df2

# %%
df2

# %%
df2_t=df2.T
df2_t["Wojtek"]=[7, "my address", "Pulawy", "1345", "Wojtek", 15, "Europe"]
df2_t["Ben's Shop"]=[4, "my address", "Pulawy", "1345", "Wojtek", 15, "Europe"]
# Out:
#             ID           Adress           City               ZIP         Name  \
# Name
#  Madeira     1     3666 21st St  San Francisco          CA 94114      Madeira
# Bready Shop  2   735 Dolores St  San Francisco          CA 94119  Bready Shop
# Super River  3      332 Hill St  San Francisco  California 94114  Super River
# Ben's Shop   4       my address         Pulawy              1345       Wojtek
# Richvalley   6  551 Alvarado St  San Francisco          CA 94114   Richvalley
# Wojtek       7       my address         Pulawy              1345       Wojtek
#
#             Employees Continent
# Name
#  Madeira           10   America
# Bready Shop        17   America
# Super River        27   America
# Ben's Shop         15    Europe
# Richvalley         22   America
# Wojtek             15    Europe
